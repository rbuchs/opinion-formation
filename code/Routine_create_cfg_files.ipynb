# %% [markdown]
# Select the parameters you want for the initial graph

# %%
import numpy as np
n = 600
m = 3
gamma = 10
tag = 'scalefree_cluster'
phis =  np.arange(0,1.01,0.01)
#phis = [0.04, 0.458, 0.96]
output_dir = '/cluster/home/buchsr/opinion-formation/cfg_files'

# %%
for i, phi in enumerate(phis):
    filename = '{0}/Run_{5}_n{1}_m{2}_gamma{3}_{4}.cfg'.format(output_dir, n, m, gamma, i+1, tag)
    print(filename)
    file_object  = open(filename, 'w')
    string =  "n : {0}\n".format(n) + "m : {0}\n".format(m) + "gamma : {0}\n".format(gamma) + "phi : {0}\n".format(phi) + "tag : {0}".format(tag)
    file_object.write(string)
    file_object.close()
# Out:
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_1.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_2.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_3.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_4.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_5.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_6.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_7.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_8.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_9.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_10.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_11.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_12.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_13.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_14.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_15.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_16.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_17.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_18.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_19.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_20.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_21.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_22.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_23.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_24.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_25.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_26.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_27.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_28.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_29.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_30.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_31.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_32.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_33.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_34.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_35.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_36.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_37.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_38.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_39.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_40.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_41.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_42.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_43.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_44.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_45.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_46.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_47.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_48.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_49.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_50.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_51.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_52.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_53.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_54.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_55.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_56.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_57.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_58.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_59.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_60.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_61.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_62.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_63.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_64.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_65.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_66.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_67.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_68.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_69.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_70.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_71.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_72.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_73.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_74.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_75.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_76.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_77.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_78.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_79.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_80.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_81.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_82.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_83.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_84.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_85.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_86.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_87.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_88.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_89.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_90.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_91.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_92.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_93.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_94.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_95.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_96.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_97.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_98.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_99.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_100.cfg
# /cluster/home/buchsr/opinion-formation/cfg_files/Run_scalefree_cluster_n600_m3_gamma10_101.cfg
