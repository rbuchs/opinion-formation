# %% [markdown]
# # Implementing the simple model - Simple graph

# %%
#Import the relevant modules
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

import OpinionGraph
import OpinionAlgorithm

# %% [markdown]
# ## Create random graph

# %%
n = 30 # number of nodes
m = 120 #number of edges
gamma = 10 #ratio #nodes/#opinions
n_opinion = int(n/gamma) #number of opinions

#Generate random graph
G1 = OpinionGraph.CreateRandom(n, m, n_opinion, simple_graph=True)

# %%
#plot the opinion graph
G1.plot()

# %%
G1.summary()
# Out:
# Total number of components: 1
# Components size: Counter({30: 1})
# All components in consensus: False
# Consensus reached: False
# Percentage of nodes in components in consensus state: 0.0

# %% [markdown]
# ## Tests of the algorithm
# ### A) With $\phi=1$, i.e. only step 1

# %%
phi = 1
n_step = 10
OpinionAlgorithm.Simulation(G1, phi, n_step, verbose=True)
# Out:
# ------------- Initial graph ------------
# ------------- Step 0 ------------
# Selected node_i : 8
# DOING STEP 1
# Neighbors of node_i : [1, 14, 18, 26, 23, 7, 2, 3, 6, 21, 5]
# Selected node_j : 26
# Nodes with opinion g_i : [4, 10, 19, 20, 29]
# Selected node_j_prime : 10
# Edge moved from (8,26) to (8,10)
# ------------- Step 1 ------------
# Selected node_i : 0
# DOING STEP 1
# Neighbors of node_i : [27, 22, 9, 5, 20, 2]
# Selected node_j : 27
# Nodes with opinion g_i : [11, 16, 23, 24, 28]
# Selected node_j_prime : 16
# Edge moved from (0,27) to (0,16)
# ------------- Step 2 ------------
# Selected node_i : 16
# DOING STEP 1
# Neighbors of node_i : [22, 1, 26, 10, 18, 29, 27, 2, 5, 25, 0]
# Selected node_j : 26
# Nodes with opinion g_i : [11, 23, 24, 28]
# Selected node_j_prime : 11
# Edge moved from (16,26) to (16,11)
# ------------- Step 3 ------------
# Selected node_i : 4
# DOING STEP 1
# Neighbors of node_i : [28, 27, 1, 2, 6]
# Selected node_j : 28
# Nodes with opinion g_i : [3, 8, 10, 14, 19, 20, 26, 29]
# Selected node_j_prime : 19
# Edge moved from (4,28) to (4,19)
# ------------- Step 4 ------------
# Selected node_i : 25
# DOING STEP 1
# Neighbors of node_i : [29, 28, 20, 19, 1, 23, 12, 24, 16]
# Selected node_j : 29
# Nodes with opinion g_i : [7, 9, 13, 15, 17, 18, 21]
# Selected node_j_prime : 13
# Edge moved from (25,29) to (25,13)
# ------------- Step 5 ------------
# Selected node_i : 18
# DOING STEP 1
# Neighbors of node_i : [26, 2, 5, 13, 8, 19, 16, 28, 20, 7]
# Selected node_j : 19
# Nodes with opinion g_i : [9, 12, 15, 17, 21, 25]
# Selected node_j_prime : 17
# Edge moved from (18,19) to (18,17)
# ------------- Step 6 ------------
# Selected node_i : 29
# DOING STEP 1
# Neighbors of node_i : [7, 28, 1, 15, 16, 10, 27]
# Selected node_j : 10
# Nodes with opinion g_i : [3, 4, 6, 8, 14, 19, 20, 26]
# Selected node_j_prime : 4
# Edge moved from (29,10) to (29,4)
# ------------- Step 7 ------------
# Selected node_i : 16
# DOING STEP 1
# Neighbors of node_i : [22, 1, 10, 18, 29, 27, 2, 5, 25, 0, 11]
# Selected node_j : 11
# Nodes with opinion g_i : [23, 24, 28]
# Selected node_j_prime : 24
# Edge moved from (16,11) to (16,24)
# ------------- Step 8 ------------
# Selected node_i : 6
# DOING STEP 1
# Neighbors of node_i : [14, 27, 21, 10, 5, 4, 8, 1, 12]
# Selected node_j : 14
# Nodes with opinion g_i : [3, 19, 20, 26, 29]
# Selected node_j_prime : 29
# Edge moved from (6,14) to (6,29)
# ------------- Step 9 ------------
# Selected node_i : 16
# DOING STEP 1
# Neighbors of node_i : [22, 1, 10, 18, 29, 27, 2, 5, 25, 0, 24]
# Selected node_j : 18
# Nodes with opinion g_i : [11, 23, 28]
# Selected node_j_prime : 23
# Edge moved from (16,18) to (16,23)

# %%
n_step = 1000
G2 = OpinionGraph.CreateRandom(n, m, n_opinion)
OpinionAlgorithm.Simulation(G2, phi, n_step, verboseBeginEnd=True)
# Out:
# ------------- Initial graph ------------
# ------------- Final graph -------------
# **** Same layout ****
# **** New layout ****

# %%
G2.summary()
# Out:
# Total number of components: 3
# Components size: Counter({15: 1, 6: 1, 9: 1})
# All components in consensus: True
# Consensus reached: True
# Percentage of nodes in components in consensus state: 1.0

# %%
G3 = OpinionGraph.CreateRandom(n, m, n_opinion)
OpinionAlgorithm.SimulationEndConsensus(G3, phi, verbose=False)
# Out:
# 348

# %%
G3.summary()
# Out:
# Total number of components: 3
# Components size: Counter({10: 1, 8: 1, 12: 1})
# All components in consensus: True
# Consensus reached: True
# Percentage of nodes in components in consensus state: 1.0

# %% [markdown]
# ### B) With $\phi=0$, i.e. only step 2

# %%
phi = 0
n_step = 30
G4 = OpinionGraph.CreateRandom(n, m, n_opinion)
OpinionAlgorithm.Simulation(G4, phi, n_step, verbose=True)
# Out:
# ------------- Initial graph ------------
# ------------- Step 0 ------------
# Selected node_i : 27
# DOING STEP 2
# Neighbors of node_i : [3, 21, 26]
# Selected node_j : 26
# ------------- Step 1 ------------
# Selected node_i : 16
# DOING STEP 2
# Neighbors of node_i : [1, 11, 13, 15, 19, 20, 24]
# Selected node_j : 15
# ------------- Step 2 ------------
# Selected node_i : 13
# DOING STEP 2
# Neighbors of node_i : [2, 18, 22, 20, 21, 28, 16]
# Selected node_j : 21
# Opinion of node 13 changed from 1 to 2
# ------------- Step 3 ------------
# Selected node_i : 18
# DOING STEP 2
# Neighbors of node_i : [1, 13, 14, 23, 20, 19, 29]
# Selected node_j : 29
# Opinion of node 18 changed from 2 to 1
# ------------- Step 4 ------------
# Selected node_i : 27
# DOING STEP 2
# Neighbors of node_i : [3, 21, 26]
# Selected node_j : 26
# ------------- Step 5 ------------
# Selected node_i : 12
# DOING STEP 2
# Neighbors of node_i : [1, 2, 5, 10, 11, 20, 14, 26, 24]
# Selected node_j : 1
# ------------- Step 6 ------------
# Selected node_i : 11
# DOING STEP 2
# Neighbors of node_i : [8, 9, 29, 22, 12, 19, 16, 26]
# Selected node_j : 9
# Opinion of node 11 changed from 0 to 1
# ------------- Step 7 ------------
# Selected node_i : 4
# DOING STEP 2
# Neighbors of node_i : [2, 14, 8, 7, 10, 26]
# Selected node_j : 10
# ------------- Step 8 ------------
# Selected node_i : 16
# DOING STEP 2
# Neighbors of node_i : [1, 11, 13, 15, 19, 20, 24]
# Selected node_j : 19
# Opinion of node 16 changed from 1 to 2
# ------------- Step 9 ------------
# Selected node_i : 3
# DOING STEP 2
# Neighbors of node_i : [2, 19, 25, 27, 23, 8, 21, 10, 9]
# Selected node_j : 10
# Opinion of node 3 changed from 1 to 2
# ------------- Step 10 ------------
# Selected node_i : 21
# DOING STEP 2
# Neighbors of node_i : [3, 5, 13, 14, 17, 28, 27, 26]
# Selected node_j : 17
# ------------- Step 11 ------------
# Selected node_i : 10
# DOING STEP 2
# Neighbors of node_i : [0, 3, 4, 5, 7, 9, 12, 20, 17, 29]
# Selected node_j : 3
# ------------- Step 12 ------------
# Selected node_i : 26
# DOING STEP 2
# Neighbors of node_i : [1, 4, 5, 8, 11, 12, 14, 21, 27, 29]
# Selected node_j : 8
# ------------- Step 13 ------------
# Selected node_i : 22
# DOING STEP 2
# Neighbors of node_i : [7, 8, 11, 13, 15, 24]
# Selected node_j : 15
# Opinion of node 22 changed from 0 to 1
# ------------- Step 14 ------------
# Selected node_i : 6
# DOING STEP 2
# ------------- Step 15 ------------
# Selected node_i : 5
# DOING STEP 2
# Neighbors of node_i : [0, 10, 28, 19, 14, 26, 21, 17, 25, 23, 29, 12]
# Selected node_j : 12
# ------------- Step 16 ------------
# Selected node_i : 5
# DOING STEP 2
# Neighbors of node_i : [0, 10, 28, 19, 14, 26, 21, 17, 25, 23, 29, 12]
# Selected node_j : 17
# Opinion of node 5 changed from 0 to 2
# ------------- Step 17 ------------
# Selected node_i : 13
# DOING STEP 2
# Neighbors of node_i : [2, 18, 22, 20, 21, 28, 16]
# Selected node_j : 20
# ------------- Step 18 ------------
# Selected node_i : 6
# DOING STEP 2
# ------------- Step 19 ------------
# Selected node_i : 22
# DOING STEP 2
# Neighbors of node_i : [7, 8, 11, 13, 15, 24]
# Selected node_j : 11
# ------------- Step 20 ------------
# Selected node_i : 13
# DOING STEP 2
# Neighbors of node_i : [2, 18, 22, 20, 21, 28, 16]
# Selected node_j : 21
# ------------- Step 21 ------------
# Selected node_i : 2
# DOING STEP 2
# Neighbors of node_i : [0, 14, 28, 23, 12, 4, 25, 3, 13]
# Selected node_j : 4
# ------------- Step 22 ------------
# Selected node_i : 15
# DOING STEP 2
# Neighbors of node_i : [1, 8, 14, 24, 22, 16]
# Selected node_j : 1
# Opinion of node 15 changed from 1 to 0
# ------------- Step 23 ------------
# Selected node_i : 9
# DOING STEP 2
# Neighbors of node_i : [1, 3, 7, 8, 17, 28, 10, 25, 19, 23, 20, 11]
# Selected node_j : 19
# Opinion of node 9 changed from 1 to 2
# ------------- Step 24 ------------
# Selected node_i : 16
# DOING STEP 2
# Neighbors of node_i : [1, 11, 13, 15, 19, 20, 24]
# Selected node_j : 24
# Opinion of node 16 changed from 2 to 0
# ------------- Step 25 ------------
# Selected node_i : 11
# DOING STEP 2
# Neighbors of node_i : [8, 9, 29, 22, 12, 19, 16, 26]
# Selected node_j : 29
# ------------- Step 26 ------------
# Selected node_i : 3
# DOING STEP 2
# Neighbors of node_i : [2, 19, 25, 27, 23, 8, 21, 10, 9]
# Selected node_j : 21
# ------------- Step 27 ------------
# Selected node_i : 21
# DOING STEP 2
# Neighbors of node_i : [3, 5, 13, 14, 17, 28, 27, 26]
# Selected node_j : 27
# Opinion of node 21 changed from 2 to 1
# ------------- Step 28 ------------
# Selected node_i : 5
# DOING STEP 2
# Neighbors of node_i : [0, 10, 28, 19, 14, 26, 21, 17, 25, 23, 29, 12]
# Selected node_j : 25
# ------------- Step 29 ------------
# Selected node_i : 3
# DOING STEP 2
# Neighbors of node_i : [2, 19, 25, 27, 23, 8, 21, 10, 9]
# Selected node_j : 2

# %%
n_step = 1000
G5 = OpinionGraph.CreateRandom(n, m, n_opinion)
OpinionAlgorithm.Simulation(G5, phi, n_step, verboseBeginEnd=True)
# Out:
# ------------- Initial graph ------------
# ------------- Final graph -------------
# **** Same layout ****
# **** New layout ****

# %%
G5.summary()
# Out:
# Total number of components: 1
# Components size: Counter({30: 1})
# All components in consensus: True
# Consensus reached: True
# Percentage of nodes in components in consensus state: 1.0

# %%
G6 = OpinionGraph.CreateRandom(n, m, n_opinion)
OpinionAlgorithm.SimulationEndConsensus(G6, phi, verbose=False)
# Out:
# 1450

# %%
G6.summary()
# Out:
# Total number of components: 1
# Components size: Counter({30: 1})
# All components in consensus: True
# Consensus reached: True
# Percentage of nodes in components in consensus state: 1.0

# %% [markdown]
# ### C) With $0<\phi<1$ , i.e. mix of steps

# %%
phi = 0.04
n_step = 1000
G7 = OpinionGraph.CreateRandom(n, m, n_opinion)
OpinionAlgorithm.Simulation(G7, phi, n_step, verboseBeginEnd=True)
# Out:
# ------------- Initial graph ------------
# ------------- Final graph -------------
# **** Same layout ****
# **** New layout ****

# %%
G8 = OpinionGraph.CreateRandom(n, m, n_opinion)
OpinionAlgorithm.SimulationEndConsensus(G8, phi, verbose=False)
# Out:
# 635

# %%
G8.summary()
# Out:
# Total number of components: 1
# Components size: Counter({30: 1})
# All components in consensus: True
# Consensus reached: True
# Percentage of nodes in components in consensus state: 1.0
