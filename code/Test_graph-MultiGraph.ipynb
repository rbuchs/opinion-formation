# %% [markdown]
# # Implementing the simple model - Multigraph

# %%
#Import the relevant modules
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

import OpinionGraph
import OpinionAlgorithm

# %% [markdown]
# ## Create random graph
# This is implemented as a `MultiGraph` from `Networkx` which can have self-loops and multi-edges. The function that creates the random graph, `OpinionGraph.CreateRandom` creates a graph with NO self-loops and NO multi-edges.

# %%
n = 30 # number of nodes
m = 120 #number of edges
gamma = 10 #ratio #nodes/#opinions
n_opinion = int(n/gamma) #number of opinions

#Generate random graph
G1 = OpinionGraph.CreateRandom(n, m, n_opinion)

# %%
#plot the opinion graph
G1.plot()

# %%
G1.summary()
# Out:
# Total number of components: 1
# Components size: Counter({30: 1})
# All components in consensus: False
# Consensus reached: False
# Percentage of nodes in components in consensus state: 0.0

# %% [markdown]
# ## Tests of the algorithm
# ### A) With $\phi=1$, i.e. only step 1

# %%
phi = 1
n_step = 10
OpinionAlgorithm.Simulation(G1, phi, n_step, verbose=True)
# Out:
# ------------- Initial graph ------------
# ------------- Step 0 ------------
# Selected node_i : 24
# DOING STEP 1
# Neighbors of node_i : [4, 10, 14, 17, 20, 21, 23, 25]
# Selected node_j : 14
# Nodes with opinion g_i : [0, 1, 5, 16, 19, 20, 26, 27, 28]
# Selected node_j_prime : 0
# Edge moved from (24,14) to (24,0)
# ------------- Step 1 ------------
# Selected node_i : 8
# DOING STEP 1
# Neighbors of node_i : [2, 6, 7, 10, 21, 20, 27, 19, 13]
# Selected node_j : 7
# Nodes with opinion g_i : [4, 6, 7, 9, 10, 12, 22, 25, 29]
# Selected node_j_prime : 10
# Edge moved from (8,7) to (8,10)
# ------------- Step 2 ------------
# Selected node_i : 4
# DOING STEP 1
# Neighbors of node_i : [0, 1, 12, 24, 25, 18, 27, 5]
# Selected node_j : 0
# Nodes with opinion g_i : [6, 7, 8, 9, 10, 12, 22, 25, 29]
# Selected node_j_prime : 25
# Edge moved from (4,0) to (4,25)
# ------------- Step 3 ------------
# Selected node_i : 10
# DOING STEP 1
# Neighbors of node_i : [2, 8, 11, 29, 27, 24, 26]
# Selected node_j : 26
# Nodes with opinion g_i : [4, 6, 7, 8, 9, 12, 22, 25, 29]
# Selected node_j_prime : 12
# Edge moved from (10,26) to (10,12)
# ------------- Step 4 ------------
# Selected node_i : 28
# DOING STEP 1
# Neighbors of node_i : [0, 13, 15, 19, 20]
# Selected node_j : 0
# Nodes with opinion g_i : [0, 1, 5, 16, 19, 20, 24, 26, 27]
# Selected node_j_prime : 1
# Edge moved from (28,0) to (28,1)
# ------------- Step 5 ------------
# Selected node_i : 25
# DOING STEP 1
# Neighbors of node_i : [0, 1, 3, 4, 15, 16, 22, 24, 27, 26]
# Selected node_j : 0
# Nodes with opinion g_i : [4, 6, 7, 8, 9, 10, 12, 22, 29]
# Selected node_j_prime : 6
# Edge moved from (25,0) to (25,6)
# ------------- Step 6 ------------
# Selected node_i : 5
# DOING STEP 1
# Neighbors of node_i : [2, 4, 26, 23, 9, 20, 21]
# Selected node_j : 23
# Nodes with opinion g_i : [0, 1, 16, 19, 20, 24, 26, 27, 28]
# Selected node_j_prime : 27
# Edge moved from (5,23) to (5,27)
# ------------- Step 7 ------------
# Selected node_i : 3
# DOING STEP 1
# Neighbors of node_i : [12, 9, 18, 29, 17, 25, 22]
# Selected node_j : 9
# Nodes with opinion g_i : [2, 11, 13, 14, 15, 17, 18, 21, 23]
# Selected node_j_prime : 2
# Edge moved from (3,9) to (3,2)
# ------------- Step 8 ------------
# Selected node_i : 25
# DOING STEP 1
# Neighbors of node_i : [1, 3, 4, 15, 16, 22, 24, 27, 26, 6]
# Selected node_j : 16
# Nodes with opinion g_i : [4, 6, 7, 8, 9, 10, 12, 22, 29]
# Selected node_j_prime : 22
# Edge moved from (25,16) to (25,22)
# ------------- Step 9 ------------
# Selected node_i : 13
# DOING STEP 1
# Neighbors of node_i : [0, 1, 8, 11, 16, 21, 14, 28, 19]
# Selected node_j : 16
# Nodes with opinion g_i : [2, 3, 11, 14, 15, 17, 18, 21, 23]
# Selected node_j_prime : 14
# Edge moved from (13,16) to (13,14)

# %%
n_step = 1000
G2 = OpinionGraph.CreateRandom(n, m, n_opinion)
OpinionAlgorithm.Simulation(G2, phi, n_step, verboseBeginEnd=True)
# Out:
# ------------- Initial graph ------------
# ------------- Final graph -------------
# **** Same layout ****
# **** New layout ****

# %%
G2.summary()
# Out:
# Total number of components: 3
# Components size: Counter({14: 1, 7: 1, 9: 1})
# All components in consensus: True
# Consensus reached: True
# Percentage of nodes in components in consensus state: 1.0

# %%
G3 = OpinionGraph.CreateRandom(n, m, n_opinion)
OpinionAlgorithm.SimulationEndConsensus(G3, phi, verbose=False)
# Out:
# 370

# %%
G3.summary()
# Out:
# Total number of components: 3
# Components size: Counter({11: 1, 10: 1, 9: 1})
# All components in consensus: True
# Consensus reached: True
# Percentage of nodes in components in consensus state: 1.0

# %% [markdown]
# ### B) With $\phi=0$, i.e. only step 2

# %%
phi = 0
n_step = 30
G4 = OpinionGraph.CreateRandom(n, m, n_opinion)
OpinionAlgorithm.Simulation(G4, phi, n_step, verbose=True)
# Out:
# ------------- Initial graph ------------
# ------------- Step 0 ------------
# Selected node_i : 17
# DOING STEP 2
# Neighbors of node_i : [12, 16, 23, 20, 21]
# Selected node_j : 23
# ------------- Step 1 ------------
# Selected node_i : 26
# DOING STEP 2
# Neighbors of node_i : [0, 1, 2, 8, 9, 15, 18, 19, 21, 23, 28, 29]
# Selected node_j : 9
# Opinion of node 26 changed from 0 to 1
# ------------- Step 2 ------------
# Selected node_i : 24
# DOING STEP 2
# Neighbors of node_i : [2, 4, 8, 11, 16, 20, 27]
# Selected node_j : 8
# Opinion of node 24 changed from 0 to 1
# ------------- Step 3 ------------
# Selected node_i : 17
# DOING STEP 2
# Neighbors of node_i : [12, 16, 23, 20, 21]
# Selected node_j : 23
# ------------- Step 4 ------------
# Selected node_i : 4
# DOING STEP 2
# Neighbors of node_i : [2, 11, 28, 10, 5, 20, 19, 18, 12, 15, 24]
# Selected node_j : 28
# Opinion of node 4 changed from 1 to 2
# ------------- Step 5 ------------
# Selected node_i : 27
# DOING STEP 2
# Neighbors of node_i : [2, 6, 10, 12, 14, 21, 22, 24]
# Selected node_j : 14
# Opinion of node 27 changed from 2 to 0
# ------------- Step 6 ------------
# Selected node_i : 0
# DOING STEP 2
# Neighbors of node_i : [9, 2, 26, 1]
# Selected node_j : 2
# ------------- Step 7 ------------
# Selected node_i : 10
# DOING STEP 2
# Neighbors of node_i : [1, 4, 6, 7, 29, 27, 11, 12, 13]
# Selected node_j : 4
# Opinion of node 10 changed from 0 to 2
# ------------- Step 8 ------------
# Selected node_i : 4
# DOING STEP 2
# Neighbors of node_i : [2, 11, 28, 10, 5, 20, 19, 18, 12, 15, 24]
# Selected node_j : 15
# Opinion of node 4 changed from 2 to 0
# ------------- Step 9 ------------
# Selected node_i : 18
# DOING STEP 2
# Neighbors of node_i : [3, 4, 5, 6, 11, 14, 26]
# Selected node_j : 26
# Opinion of node 18 changed from 0 to 1
# ------------- Step 10 ------------
# Selected node_i : 15
# DOING STEP 2
# Neighbors of node_i : [1, 4, 7, 13, 28, 25, 26, 16]
# Selected node_j : 25
# Opinion of node 15 changed from 0 to 2
# ------------- Step 11 ------------
# Selected node_i : 17
# DOING STEP 2
# Neighbors of node_i : [12, 16, 23, 20, 21]
# Selected node_j : 20
# Opinion of node 17 changed from 2 to 0
# ------------- Step 12 ------------
# Selected node_i : 20
# DOING STEP 2
# Neighbors of node_i : [3, 4, 7, 8, 9, 11, 14, 17, 24, 23]
# Selected node_j : 23
# Opinion of node 20 changed from 0 to 2
# ------------- Step 13 ------------
# Selected node_i : 4
# DOING STEP 2
# Neighbors of node_i : [2, 11, 28, 10, 5, 20, 19, 18, 12, 15, 24]
# Selected node_j : 20
# Opinion of node 4 changed from 0 to 2
# ------------- Step 14 ------------
# Selected node_i : 7
# DOING STEP 2
# Neighbors of node_i : [3, 10, 12, 20, 15, 16, 25]
# Selected node_j : 12
# Opinion of node 7 changed from 1 to 2
# ------------- Step 15 ------------
# Selected node_i : 15
# DOING STEP 2
# Neighbors of node_i : [1, 4, 7, 13, 28, 25, 26, 16]
# Selected node_j : 26
# Opinion of node 15 changed from 2 to 1
# ------------- Step 16 ------------
# Selected node_i : 28
# DOING STEP 2
# Neighbors of node_i : [4, 9, 11, 15, 19, 23, 25, 26, 29]
# Selected node_j : 19
# Opinion of node 28 changed from 2 to 0
# ------------- Step 17 ------------
# Selected node_i : 10
# DOING STEP 2
# Neighbors of node_i : [1, 4, 6, 7, 29, 27, 11, 12, 13]
# Selected node_j : 4
# ------------- Step 18 ------------
# Selected node_i : 14
# DOING STEP 2
# Neighbors of node_i : [1, 13, 20, 18, 27, 19, 16, 23, 22]
# Selected node_j : 18
# Opinion of node 14 changed from 0 to 1
# ------------- Step 19 ------------
# Selected node_i : 19
# DOING STEP 2
# Neighbors of node_i : [4, 11, 14, 16, 28, 26]
# Selected node_j : 26
# Opinion of node 19 changed from 0 to 1
# ------------- Step 20 ------------
# Selected node_i : 10
# DOING STEP 2
# Neighbors of node_i : [1, 4, 6, 7, 29, 27, 11, 12, 13]
# Selected node_j : 12
# ------------- Step 21 ------------
# Selected node_i : 28
# DOING STEP 2
# Neighbors of node_i : [4, 9, 11, 15, 19, 23, 25, 26, 29]
# Selected node_j : 15
# Opinion of node 28 changed from 0 to 1
# ------------- Step 22 ------------
# Selected node_i : 11
# DOING STEP 2
# Neighbors of node_i : [3, 4, 10, 18, 19, 16, 29, 24, 21, 20, 28]
# Selected node_j : 29
# ------------- Step 23 ------------
# Selected node_i : 12
# DOING STEP 2
# Neighbors of node_i : [4, 6, 7, 9, 10, 17, 27, 16, 29]
# Selected node_j : 16
# Opinion of node 12 changed from 2 to 1
# ------------- Step 24 ------------
# Selected node_i : 16
# DOING STEP 2
# Neighbors of node_i : [3, 5, 6, 7, 8, 11, 12, 13, 14, 15, 17, 21, 19, 24]
# Selected node_j : 24
# ------------- Step 25 ------------
# Selected node_i : 18
# DOING STEP 2
# Neighbors of node_i : [3, 4, 5, 6, 11, 14, 26]
# Selected node_j : 14
# ------------- Step 26 ------------
# Selected node_i : 29
# DOING STEP 2
# Neighbors of node_i : [6, 10, 11, 12, 23, 26, 28]
# Selected node_j : 10
# Opinion of node 29 changed from 1 to 2
# ------------- Step 27 ------------
# Selected node_i : 15
# DOING STEP 2
# Neighbors of node_i : [1, 4, 7, 13, 28, 25, 26, 16]
# Selected node_j : 26
# ------------- Step 28 ------------
# Selected node_i : 3
# DOING STEP 2
# Neighbors of node_i : [2, 23, 18, 11, 20, 7, 13, 16]
# Selected node_j : 2
# ------------- Step 29 ------------
# Selected node_i : 10
# DOING STEP 2
# Neighbors of node_i : [1, 4, 6, 7, 29, 27, 11, 12, 13]
# Selected node_j : 11
# Opinion of node 10 changed from 2 to 1

# %%
n_step = 1000
G5 = OpinionGraph.CreateRandom(n, m, n_opinion)
OpinionAlgorithm.Simulation(G5, phi, n_step, verboseBeginEnd=True)
# Out:
# ------------- Initial graph ------------
# ------------- Final graph -------------
# **** Same layout ****
# **** New layout ****

# %%
G5.summary()
# Out:
# Total number of components: 1
# Components size: Counter({30: 1})
# All components in consensus: True
# Consensus reached: True
# Percentage of nodes in components in consensus state: 1.0

# %%
G6 = OpinionGraph.CreateRandom(n, m, n_opinion)
OpinionAlgorithm.SimulationEndConsensus(G6, phi, verbose=False)
# Out:
# 707

# %%
G6.summary()
# Out:
# Total number of components: 1
# Components size: Counter({30: 1})
# All components in consensus: True
# Consensus reached: True
# Percentage of nodes in components in consensus state: 1.0

# %% [markdown]
# ### C) With $0<\phi<1$ , i.e. mix of steps

# %%
phi = 0.04
n_step = 1000
G7 = OpinionGraph.CreateRandom(n, m, n_opinion)
OpinionAlgorithm.Simulation(G7, phi, n_step, verboseBeginEnd=True)
# Out:
# ------------- Initial graph ------------
# ------------- Final graph -------------
# **** Same layout ****
# **** New layout ****

# %%
G8 = OpinionGraph.CreateRandom(n, m, n_opinion)
OpinionAlgorithm.SimulationEndConsensus(G8, phi, verbose=False)
# Out:
# 729

# %%
G8.summary()
# Out:
# Total number of components: 1
# Components size: Counter({30: 1})
# All components in consensus: True
# Consensus reached: True
# Percentage of nodes in components in consensus state: 1.0
