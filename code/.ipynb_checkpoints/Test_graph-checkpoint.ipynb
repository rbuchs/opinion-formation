# %% [markdown]
# # Implementing the simple model

# %%
#Import the relevant modules
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

import OpinionGraph
import OpinionAlgorithm

# %% [markdown]
# ## Create random graph

# %%
n = 30
m = 120
n_opinion = 4
G = OpinionGraph.CreateRandom(n, m, n_opinion)

# %% [markdown]
# ## Some tests

# %%
phi = 0.5
n_step = 10
OpinionAlgorithm.Simulation(G, phi, n_step, verbose=True)
# Out:
# ------------- Initial graph ------------
# ------------- Step 0 ------------
# Node i selected : 18
# DOING STEP 2
# Opinion of node 18 changed from 3 to 2
# ------------- Step 1 ------------
# Node i selected : 29
# DOING STEP 1
# Edge moved from node 0 to node 10
# ------------- Step 2 ------------
# Node i selected : 3
# DOING STEP 1
# Edge moved from node 6 to node 24
# ------------- Step 3 ------------
# Node i selected : 7
# DOING STEP 2
# Opinion of node 7 changed from 1 to 2
# ------------- Step 4 ------------
# Node i selected : 0
# DOING STEP 1
# Edge moved from node 3 to node 27
# ------------- Step 5 ------------
# Node i selected : 16
# DOING STEP 1
# Edge moved from node 11 to node 10
# ------------- Step 6 ------------
# Node i selected : 15
# DOING STEP 2
# Opinion of node 15 changed from 0 to 3
# ------------- Step 7 ------------
# Node i selected : 2
# DOING STEP 1
# Edge moved from node 7 to node 14
# ------------- Step 8 ------------
# Node i selected : 24
# DOING STEP 2
# Opinion of node 24 changed from 0 to 2
# ------------- Step 9 ------------
# Node i selected : 11
# DOING STEP 2
# Opinion of node 11 changed from 0 to 3

# %%
phi = 0.5
n_step = 10
OpinionAlgorithm.SimulationBeginEnd(G, phi, n_step)
# Out:
# ------------- Initial graph ------------
# ------------- Final graph ------------
